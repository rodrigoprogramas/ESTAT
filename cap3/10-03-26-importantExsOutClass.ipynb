# %%
#6,9,20,26

#Exercício 6

#X: Número de animais adotados, por dia

#P(X >= 2 ) = 0.75

#P(X = 3 | X >=2 ) = P(X =3) E P(X>=2) / P(X>=2) = P(X=3) / P(X>=2) = 1/3 / 0.75

print(f'A probablidade de serem adotados três animais num dia em que foram adotados pelo menos dois é {(1/3) / 0.75}')
#B +1/3 +/14 = 0.75
#b 1/6

#1/20 + a + 1/6 + 1/3 +1/4 = 1

#a = 1/5

print(f'O valor médio é {(0*1/20)+(1*1/5)+(2*1/6)+(3*1/3)+(4*1/4)}')
# Out:
# A probablidade de serem adotados três animais num dia em que foram adotados pelo menos dois é 0.4444444444444444
# O valor médio é 2.533333333333333

# %%
#Exercício 9

#P(X<4 | X>1) = P(X<4) E P(X>1) / P(X>1)  =c*(1/3+1/2) / c* (1/2+1/3+1/4)

p_menos_4_mais_do_que_um = (1/3+1/2) / (1/2+1/3+1/4)

print(f'{p_menos_4_mais_do_que_um:.2f}')

#9.2 perguntar stora
# Out:
# 0.77
